# %% [markdown]
# <a href="https://colab.research.google.com/github/dronshingote2-cell/DSP/blob/main/DSP_Experiment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=[1,2,"a",8.5,[7,8],(4,"a")]
print(a)
print(type(a))
# Out:
# [1, 2, 'a', 8.5, [7, 8], (4, 'a')]
# <class 'list'>

# %%
0# This is a comment. It will not be executed.
print("Hello")
# Out:
# Hello

# %%
a, b = map(int , input("Enter value for a and b: ").split())
print("Sum =", a+b)
# Out:
# Enter value for a and b: 10 5
# Sum = 15

# %%
x = 5
y = 3.14
z = "Hi"
print(x,y,z)
# Out:
# 5 3.14 Hi

# %%
x = 10
print(type(x))
x = "Now a string"
print(type(x))
# Out:
# <class 'int'>
# <class 'str'>

# %%
a = b = c = 100
print(a, b, c)
x, y, z = 1, 2.5, "Python"
print(x, y, z)
# Out:
# 100 100 100
# 1 2.5 Python

# %%
a=10
print(id(a))
b=a
print(id(b))
a= 20
print(id(a))
# Out:
# 11645640
# 11645640
# 11645960

# %%
x = 10
del x
# print(x) # This line causes a NameError because x has been deleted.

# %%
#Arithmetic Operators
a = 15
b = 4
print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Floor Division:", a // b)
print("Modulus:", a % b)
print("Exponentiation:", a ** b)
# Out:
# Addition: 19
# Subtraction: 11
# Multiplication: 60
# Division: 3.75
# Floor Division: 3
# Modulus: 3
# Exponentiation: 50625

# %%
#Relational or Comaprison operators
a = 13
b = 33
print(a > b)
print(a < b)
print(a == b)
print(a != b)
print(a >= b)
print(a <= b)
# Out:
# False
# True
# False
# True
# False
# True

# %%
#Logical Operators
a = True
b = False
print(a and b)
print(a or b)
print(not a)
# Out:
# False
# True
# False

# %%
#Bitwise Operators
a = 10
b = 4
print(a & b)
print(a | b)
print(~a)
print(a ^ b)
print(a >> 2)
print(a << 2)
# Out:
# 0
# 14
# -11
# 14
# 2
# 40

# %%
#Assignment Operators
a = 10
b = a
print(b)
b += a
print(b)
b -= a
print(b)
b *= a
print(b)
b <<= a
print(b)
# Out:
# 10
# 20
# 10
# 100
# 102400

# %%
#Identity Operators
a = 10
b = 20
c = a
print(a is not b)
print(a is c)
# Out:
# True
# True

# %%
#Membership Operators
x = 24
y = 20
my_list = [10, 20, 30, 40, 50]
if (x not in my_list):
  print("x is NOT present in given list")
else:
  print("x is present in given list")
if (y in my_list):
  print("y is present in given list")
else:
  print("y is NOT present in given list")
# Out:
# x is NOT present in given list
# y is present in given list

# %%
#Numeric Data Type
a = 5
b = 5.0
c = 2 + 4j
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
#Sequence Data Type---> String
s = 'Welcome to the Geeks World'
print(s)
print(type(s))
# access string with index
print(s[1])
print(s[-1])
# Out:
# Welcome to the Geeks World
# <class 'str'>
# e
# d

# %%
#Sequence Data Type---> List
a = [1, 2, 3]
print(a)
b = ["Geeks", "For", "Geeks", 4, 5]
print(b[3])
print(b[-3])
# Out:
# [1, 2, 3]
# 4
# Geeks

# %%
#Sequence Data Type---> Tuple
t1 = (1,)
print(type(t1))
t2 = ('Geeks', 'For', 'Geeks', 1, 2)
print(t2[3])
print(t2[-3])
# Out:
# <class 'tuple'>
# 1
# Geeks

# %%
#Boolean Data Type
print(type(True))
print(type(False))
# Out:
# <class 'bool'>
# <class 'bool'>

# %%
#Set Data Type
s1 = {"a", "a", "b", "c", "b"}
print(s1)
s2 = {"Geeks", "For", "Geeks"}
for i in s2:
  print(i)
# Out:
# {'b', 'a', 'c'}
# For
# Geeks

# %%
#Dictionary Data Type
d = {1: 'Geeks', 2: 'For', 3: 'Geeks'}
print(d[1])
print(d.get(2))
# Out:
# Geeks
# For

# %%
number = int(input('Enter a number: '))
# check if number is greater than 0
if number > 0:
  print('number is a positive number.')
else:
  print('number is a negative number.')
# Out:
# Enter a number: 10
# number is a positive number.

# %%
number = -5
if number > 0:
  print('Positive number')
elif number < 0:
  print('Negative number')
else:
  print('Zero')
print('This statement is always executed')
# Out:
# Negative number
# This statement is always executed

# %%
score = int(input("Enter the student's score: "))
if score >= 90:
  print("Grade: A")
elif score >= 80:
  print("Grade: B")
elif score >= 70:
  print("Grade: C")
elif score >= 60:
  print("Grade: D")
else:
  print("Grade: F")
# Out:
# Enter the student's score: 5
# Grade: F

# %%
a, b = 10, 20
if a < 50:
    if b < 100:
      print("a is less than 50 and b is less than 100")
    else:
      print("a is less than 50 but b is not less than 100")
else:
    print("a is not less than 50")
# Out:
# a is less than 50 and b is less than 100

# %%
# Largest of 3 numbers
num1 = int(input("Enter first number: "))
num2 = float(input("Enter second number: "))
num3 = float(input("Enter third number: "))
if (num1 >= num2) and (num1 >= num3):
    largest = num1
elif (num2 >= num1) and (num2 >= num3):
    largest = num2
else:
    largest = num3
print("The largest number is", largest)
# Out:
# Enter first number: 63
# Enter second number: 6
# Enter third number: 6
# The largest number is 63

# %%
#Check number is Positive or Negative
num = int(input("Enter a number: "))
if num > 0:
  print("Positive number")
elif num == 0:
  print("Zero")
else:
  print("Negative number")
# Out:
# Enter a number: 6
# Positive number

# %%
#Odd or Even
num = int(input("Enter a number: "))
if (num % 2) == 0:
  print("{0} is Even".format(num))
else:
  print("{0} is Odd".format(num))
# Out:
# Enter a number: 6
# 6 is Even

# %%
# iterate from i = 0 to i = 3
for i in range(0, 4):
  print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
# iterate from i = 0 to i = 3
for i in range(1, 4):
  print(i)
# Out:
# 1
# 2
# 3

# %%
# iterate from i = 0 to i = 3
for i in range(0, 10,2):
  print(i)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
# iterate from i = 0 to i = 3
for i in range(1, 10,2):
  print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
n = int(input("Enter a number"))
for i in range(0, n):
  print(i)
# Out:
# Enter a number6
# 0
# 1
# 2
# 3
# 4
# 5

# %%
list1 = ['MIT', 'WPU', 'Pune']
for i in list1:
  print(i)
# Out:
# MIT
# WPU
# Pune

# %%
list1 = ['MIT', 'WPU', 'Pune']
for i in list1:
  if i == 'Pune':
    break
  print(i)
# Out:
# MIT
# WPU

# %%
list1 = ['MIT', 'WPU', 'Pune','India']
for i in list1:
  if i == 'Pune':
    continue
print(i)
# Out:
# India

# %%
for i in range(5):
  if i == 3:
    break
print(i)
# Out:
# 3

# %%
for i in range(5):
  if i == 3:
    continue
print(i)
# Out:
# 4

# %%
n = 10
# use pass inside if statement
if n > 10:
  pass

print('Hello')
# Out:
# Hello

# %%
x = 10
if x > 5:
  pass # Code will be added later
else:
  print("x is 5 or less")
